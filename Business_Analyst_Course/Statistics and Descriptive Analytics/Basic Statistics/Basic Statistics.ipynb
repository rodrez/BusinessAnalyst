# %% [markdown]
# #Libraries, directory and data

# %%
#Change directory
# %cd /content/drive/MyDrive/Personal/Business Analyst course/Part 1 - Statistics and Descriptive Analytics/Basics

# %%
#Libraries
import pandas as pd
import seaborn as sns

# %%
#dataset
df = pd.read_csv("Baseball.csv")
df.head()

# %% [markdown]
# #Mean

# %%
#Mean of Runs scored
df.RS.mean()

# %%
#Mean of Runs scored by the Arizona (ARI) team
df.loc[df.Team == "ARI"].RS.mean()

# %%
#Mean of Runs scored by the Arizona since 2005
df.loc[(df.Team == "ARI") & (df.Year > 2005)].RS.mean()

# %%
#Question - What is the mean of the Runs Allowed (RA)
# by the chicago (CHC) team until 2007
df.loc[(df.Team == "CHC") & (df.Year < 2007)].RA.mean()

# %% [markdown]
# #Median

# %%
#Median and mean of Wins
print(df.W.mean())
print(df.W.median())

# %%
#Question - What is the median of Wins of the Baltimore team (BA)
df.loc[df.Team == "BAL"].W.median()

# %% [markdown]
# #Mode

# %%
#Mode of On-Base Percentage (OBP)
print(df.OBP.mode())
print(df.OBP.median())
print(df.OBP.mean())

# %%
#Question - Mode of OBP during the year 2010
df.loc[df.Year == 2010].OBP.mode()

# %% [markdown]
# #Correlation

# %%
#selecting variables
df_corr = df[["RS", "RA", "W"]]
df_corr.head(1)

# %%
#correlation matrix
df_corr.corr()

# %%
#correlation heatmap
sns.heatmap(df_corr.corr(),
            annot = True,
            fmt = '.2g',
            center = 0,
            cmap = 'coolwarm',
            linewidths = 1,
            linecolor = 'black')

# %% [markdown]
# #Challenge run a correlation
# #matrix and heatmap with variables
# #OBP, SLG and BA.
# #Change 2 parameters in the heatmap function.

# %%
#Running a correlation matrix and heatmap between OBP, SLG and BA
df_corr2 = df[["OBP", "SLG", "BA"]]

# %%
#correlation matrix
df_corr2.corr()

# %%
#correlation heatmap2
sns.heatmap(df_corr2.corr(),
            annot = True,
            fmt = '.1g',
            center = 0.7,
            cmap = 'rocket',
            linewidths = 2,
            linecolor = 'white')

# %% [markdown]
# #Standard Deviation

# %%
#Standard deviation
print(df.OOBP.mean())
print(df.OOBP.std())

# %%
#Standard deviation of BA
print(df.BA.mean())
print(df.BA.std())
