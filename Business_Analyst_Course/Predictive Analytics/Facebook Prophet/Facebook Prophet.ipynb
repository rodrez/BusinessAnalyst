# %% [markdown]
# #Directory, libraries and data

# %%
# %cd /content/drive/MyDrive/Business Analyst course/Predictive Analytics/Facebook Prophet
# Out:
# /content/drive/MyDrive/Business Analyst course/Predictive Analytics/Facebook Prophet

# %%
#Import libraries
import numpy as np
import pandas as pd
from fbprophet import Prophet

# %%
#get the data
df = pd.read_csv("Udemy_wikipedia_visits.csv")
df.head()
# Out:
#        Date  Udemy  Easter  Christmas  Black Friday
# 0  1/1/2016    311       0          0             0
# 1  1/2/2016    564       0          0             0
# 2  1/3/2016    517       0          0             0
# 3  1/4/2016    652       0          0             0
# 4  1/5/2016    756       0          0             0

# %%
#plot
df.Udemy.plot(figsize = (9,6))

# %% [markdown]
# #Data Preparation

# %%
#Date Variable
df.Date = pd.to_datetime(df.Date,
                         format = "%m/%d/%Y")
df.Date
# Out:
# 0      2016-01-01
# 1      2016-01-02
# 2      2016-01-03
# 3      2016-01-04
# 4      2016-01-05
#           ...
# 1822   2020-12-27
# 1823   2020-12-28
# 1824   2020-12-29
# 1825   2020-12-30
# 1826   2020-12-31
# Name: Date, Length: 1827, dtype: datetime64[ns]

# %%
#Renaming Variables
df = df.rename(columns = {'Date': 'ds',
                          'Udemy': 'y'})
df.head(1)
# Out:
#           ds    y  Easter  Christmas  Black Friday
# 0 2016-01-01  311       0          0             0

# %% [markdown]
# #dynamic Holidays

# %%
#Easter
easter_dates = pd.to_datetime(df[df.Easter == 1].ds)
easter = pd.DataFrame({'holiday': 'easter',
                       'ds': easter_dates,
                       'lower_window': -5,
                       'upper_window': 2})
easter
# Out:
#      holiday         ds  lower_window  upper_window
# 86    easter 2016-03-27            -5             2
# 471   easter 2017-04-16            -5             2
# 821   easter 2018-04-01            -5             2
# 1206  easter 2019-04-21            -5             2
# 1563  easter 2020-04-12            -5             2

# %%
#Black Friday
bf_dates = pd.to_datetime(df[df['Black Friday'] == 1].ds)
bf = pd.DataFrame({'holiday': 'black_friday',
                   'ds': bf_dates,
                   'lower_window': -7,
                   'upper_window': 5})
bf
# Out:
#            holiday         ds  lower_window  upper_window
# 329   black_friday 2016-11-25            -7             5
# 693   black_friday 2017-11-24            -7             5
# 1057  black_friday 2018-11-23            -7             5
# 1428  black_friday 2019-11-29            -7             5
# 1792  black_friday 2020-11-27            -7             5

# %%
#Combine events
holidays = pd.concat([easter, bf])
holidays
# Out:
#            holiday         ds  lower_window  upper_window
# 86          easter 2016-03-27            -5             2
# 471         easter 2017-04-16            -5             2
# 821         easter 2018-04-01            -5             2
# 1206        easter 2019-04-21            -5             2
# 1563        easter 2020-04-12            -5             2
# 329   black_friday 2016-11-25            -7             5
# 693   black_friday 2017-11-24            -7             5
# 1057  black_friday 2018-11-23            -7             5
# 1428  black_friday 2019-11-29            -7             5
# 1792  black_friday 2020-11-27            -7             5

# %%
#Remove events from main dataframe
df = df.drop(columns = ["Easter", "Black Friday"])
df.head()
# Out:
#           ds    y  Christmas
# 0 2016-01-01  311          0
# 1 2016-01-02  564          0
# 2 2016-01-03  517          0
# 3 2016-01-04  652          0
# 4 2016-01-05  756          0

# %% [markdown]
# #Facebook Prophet

# %%
#Training and test split
test_days = 31
training_set = df.iloc[:-test_days,:]
test_set = df.iloc[-test_days:, : ]
print(test_set.head(1))
print(training_set.tail(1))
# Out:
#              ds     y  Christmas
# 1796 2020-12-01  2393          0
#              ds     y  Christmas
# 1795 2020-11-30  2551          0

# %%
#Facebook Prophet Model
m = Prophet(growth= 'linear',
            yearly_seasonality = True,
            weekly_seasonality = True,
            daily_seasonality = False,
            holidays = holidays,
            seasonality_mode = "multiplicative",
            seasonality_prior_scale = 10,
            holidays_prior_scale = 10,
            changepoint_prior_scale = 0.05)
m.add_regressor('Christmas')
m.fit(training_set)

# %%
#Coefficient Regressor
from fbprophet.utilities import regressor_coefficients
regressor_coefficients(m)
# Out:
#    regressor  regressor_mode  center  coef_lower      coef  coef_upper
# 0  Christmas  multiplicative     0.0   -0.295236 -0.295236   -0.295236

# %% [markdown]
# #Accuracy assessment

# %%
#Create future dataframe
future = m.make_future_dataframe(periods = test_days,
                                 freq = 'D')
future = pd.concat([future, df.iloc[:,2:]],
                   axis = 1)
future.head(2)
# Out:
#           ds  Christmas
# 0 2016-01-01          0
# 1 2016-01-02          0

# %%
#Forecasting
forecast = m.predict(future)
forecast.head()
# Out:
#           ds       trend  ...  additive_terms_upper        yhat
# 0 2016-01-01  437.127060  ...                   0.0  460.269171
# 1 2016-01-02  436.299462  ...                   0.0  403.061592
# 2 2016-01-03  435.471863  ...                   0.0  429.372462
# 3 2016-01-04  434.644265  ...                   0.0  533.409143
# 4 2016-01-05  433.816667  ...                   0.0  551.248388
#
# [5 rows x 34 columns]

# %%
#Retrieve predictions
predictions = forecast.yhat[-test_days:]
predictions[:2]
# Out:
# 1796    3023.300851
# 1797    2802.796041
# Name: yhat, dtype: float64

# %%
#MAE RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
print(mean_absolute_error(test_set['y'], predictions))
print(np.sqrt(mean_squared_error(test_set['y'], predictions)))
# Out:
# 219.47209415743265
# 299.14792952647025

# %% [markdown]
# #Visualization

# %%
#forecast
m.plot(forecast);

# %%
#plot components
m.plot_components(forecast);

# %% [markdown]
# #Cross-validation

# %%
#CV
from fbprophet.diagnostics import cross_validation
df_cv = cross_validation(model = m,
                         horizon = '31 days',
                         initial = '1500 days',
                         parallel = "processes")
df_cv.head()
# Out:
# INFO:fbprophet:Making 18 forecasts with cutoffs between 2020-02-09 12:00:00 and 2020-10-30 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f4709116ed0>
#           ds         yhat   yhat_lower   yhat_upper     y              cutoff
# 0 2020-02-10  1420.198954  1293.659902  1547.669856  1611 2020-02-09 12:00:00
# 1 2020-02-11  1468.451498  1340.591975  1599.573731  1528 2020-02-09 12:00:00
# 2 2020-02-12  1466.666437  1341.266445  1592.860429  1365 2020-02-09 12:00:00
# 3 2020-02-13  1436.940868  1313.406194  1572.003523  1487 2020-02-09 12:00:00
# 4 2020-02-14  1301.940803  1171.318939  1429.888151  1265 2020-02-09 12:00:00

# %%
#Measure the error
print(mean_absolute_error(df_cv['y'], df_cv['yhat']))
print(np.sqrt(mean_squared_error(df_cv['y'], df_cv['yhat'])))
# Out:
# 374.98934197300287
# 526.6066550954313

# %% [markdown]
# #Parameter Tuning

# %%
#Grid
from sklearn.model_selection import ParameterGrid
param_grid = {'seasonality_prior_scale': [5, 10, 20],
              'holidays_prior_scale': [5, 10, 20],
              'changepoint_prior_scale': [0.01, 0.05, 0.1]}
grid = ParameterGrid(param_grid)
list(grid)[:3]
# Out:
# [{'changepoint_prior_scale': 0.01,
#   'holidays_prior_scale': 5,
#   'seasonality_prior_scale': 5},
#  {'changepoint_prior_scale': 0.01,
#   'holidays_prior_scale': 5,
#   'seasonality_prior_scale': 10},
#  {'changepoint_prior_scale': 0.01,
#   'holidays_prior_scale': 5,
#   'seasonality_prior_scale': 20}]

# %%
#hyperparameter
rmse = []

#Parameter tuning loop
for params in grid:
  #model
  m = Prophet(growth = 'linear',
              yearly_seasonality = True,
              weekly_seasonality = True,
              daily_seasonality = False,
              seasonality_mode = 'multiplicative',
              seasonality_prior_scale = params['seasonality_prior_scale'],
              holidays_prior_scale = params['holidays_prior_scale'],
              changepoint_prior_scale = params['changepoint_prior_scale'])
  m.add_regressor('Christmas')
  m.fit(training_set)

  #cross_validation
  df_cv = cross_validation(model = m,
                           horizon = '31 days',
                           initial = '1500 days',
                           parallel = "processes")

  #get the error
  error = np.sqrt(mean_squared_error(df_cv['y'], df_cv['yhat']))

  #store the results
  rmse.append(error)

# %%
#Fetch the best parameters
best_params = grid[np.argmin(rmse)]
print(best_params)
# Out:
# {'seasonality_prior_scale': 5, 'holidays_prior_scale': 10, 'changepoint_prior_scale': 0.1}
